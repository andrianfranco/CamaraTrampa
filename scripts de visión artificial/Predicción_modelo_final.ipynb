# %%
#!/usr/bin/env python
# coding: utf-8

###################################### Librerias utilizadas ###################################

from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, Input
#from keras.optimizers import Adam
from keras.callbacks import TensorBoard, ModelCheckpoint
from keras.utils import np_utils
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator     # Generador de imagenes.
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from keras.applications.vgg19 import VGG19
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import cv2
import os

get_ipython().run_line_magic('matplotlib', 'inline')

# Librerias para metricas de desempeño y matriz de confusion
from sklearn import metrics                                  # Funcion para el calculo de metricas de desempeño, la de abajo hace lo mismo pero todo por separado.
from sklearn.metrics import confusion_matrix, f1_score, roc_curve, precision_score, recall_score, accuracy_score, roc_auc_score
from mlxtend.plotting import plot_confusion_matrix           # Paquete para ver matriz  de confusion en interfaz grafica.

import numpy as np
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

#Librerias para Generar data Augmentation
from keras.preprocessing.image import ImageDataGenerator 
from PIL import ImageFile

#Libreria para cargar modelo
from keras.models import load_model

# Libreria para obtener ruta de archivo actual
import pathlib

################################# Ingreso de parametros #########################################

pathInicial = str(pathlib.Path().absolute()) + "\\" # Path obtenido: ~/modelo

print("**** Ingreso de parametros ****\n")
modelVGG = int(input(" Modelo a utilizar: \n VGG16 --> Ingresar 0 \n VGG19 --> Ingresar 1\n"))
if not modelVGG:
    modelVGG = 16
    porcentaje = 0.99 # 8 errores en 100 fotos, 21 desconocidas (Bajando mas el valor, se comienzan a tener muchos errores)
                                                            #   (Aumentando el valor, los resultados son similares pero muchas imagenes desconocidos)
else:
    modelVGG = 19 
    porcentaje = 0.95 # 5 errores en 100 fotos, 13 desconocidas (Bajando  el valor  , se comienzan a tener muchos errores)
                                                            #   (Aumentando el valor, los resultados son similares pero muchas imagenes desconocidos)

tipoModelo = int(input("Tipo de set de datos: \n Diurno --> Ingresar 0 \n Nocturno --> Ingresar 1\n"))
if not tipoModelo:
    tipoModelo = "Diurno"
    pathAux = "Diurnas/"
    model_dir    = pathInicial + r"Backups\Diurno\model_VGG"+str(modelVGG)+"_500E_16B_"+str(tipoModelo)+".h5" 

else:
    tipoModelo = "Nocturno" 
    pathAux = "Nocturnas/"
    model_dir    = pathInicial + r"Backups\Nocturno\model_VGG"+str(modelVGG)+"_500E_16B_"+str(tipoModelo)+".h5" 

################################# Configuracion de parametros ###################################

width_shape  = 224  # Ancho de imagen (Ancho tipico de VGG16 y VGG19)
height_shape = 224  # Alto  de imagen (Alto tipico de VGG16 y VGG19)

############################### Excepciones ####################################################

if not os.path.exists(model_dir):
    raise FileNotFoundError("El archivo no existe o no se pudo abrir")
    
########################################### Predicción ######################################################################

custom_Model= load_model(model_dir)

names = ['Carpincho','Ciervo','Gato montes','Oveja','Puma','Vaca']     # Clases de nuestro dataset.
modelt= custom_Model                                                   # Modelo entrenado.

#administracion de directorios

#Renombramos imagenes
newImagesPath = pathInicial + r"newImages\\"
procesadasPath = pathInicial + r"Procesadas\\" + pathAux
lista = os.listdir(newImagesPath)                        # leemos lista de archivos. Se guardan nombre de carpeta o archivo.extension.

aux = 0
for file in lista:
    file = file[:-4]                                     # borramos ultimos 4 valores ".jpg"
    lista[aux]=file
    aux += 1

for g in range(len(lista)):                              # len(lista) devuelve cantidad de elementos
    path=newImagesPath + lista[g] + ".jpg"
    imaget = cv2.imread(path)
    imaget = cv2.resize((imaget), (width_shape, height_shape), interpolation = cv2.INTER_AREA) # Redimensionado de imagen
      
    #cv2.INTER_AREA: Esto se usa cuando necesitamos reducir una imagen.
    #cv2.INTER_CUBIC: Esto es lento pero más eficiente.
    #cv2.INTER_LINEAR: Esto se usa principalmente cuando se requiere hacer zoom. Esta es la técnica de interpolación predeterminada en OpenCV.
    xt     = np.asarray(imaget)
    xt     = preprocess_input(xt)                                       # Aplicado de preprocesamiento aplicado a las imagenes de entrenamiento y validacion.
    xt     = np.expand_dims(xt,axis=0)
    preds  = modelt.predict(xt)                                         # Predict devuelve las predicciones, el argumento con mayor valor de las predicciones correspondera con la clase mas probable
    
    print("prediccion N°:", g+1)
    print("animal detectado:", names[np.argmax(preds)])
    print("np.max(preds):", np.max(preds))
    print("preds:", preds)
    
    if (np.max(preds) >= porcentaje): # Si el porcentaje de certeza es < al valor asignado por el modelo almacenamos imagen en "desconocido"
        
        # Organizacion de directorios
        if (names[np.argmax(preds)]   == 'Carpincho'):
            directorioPath            =  procesadasPath + "Carpincho/"
            tipo                      =  "Carpincho"
    
        elif (names[np.argmax(preds)] == 'Ciervo'):
            directorioPath            =  procesadasPath + "Ciervo/"
            tipo                      =  "Ciervo"
            
        elif (names[np.argmax(preds)] == 'Gato montes'):
            directorioPath            =  procesadasPath + "Gato montes/"
            tipo                      =  "Gato montes"
                
        elif (names[np.argmax(preds)] == 'Oveja'):
            directorioPath            =  procesadasPath + "Oveja/"
            tipo                      =  "Oveja"
                
        elif (names[np.argmax(preds)] == 'Puma'):
            directorioPath            =  procesadasPath + "Puma/"
            tipo                      =  "Puma"
                
        elif (names[np.argmax(preds)] == 'Vaca'):
            directorioPath            =  procesadasPath + "Vaca/"
            tipo                      =  "Vaca"

    else:
        directorioPath                =  procesadasPath + "Desconocido/"
        tipo                          =  "Desconocido"
        print("porcentaje de certeza menor al " + str(porcentaje*100)+"% --> Objeto desconocido")
    
    print("\n")
    
                    
    os.rename(newImagesPath + lista[g] + ".jpg", directorioPath + lista[g] + "-" + tipo + ".jpg")
    g=g+1
# Out:
# Using TensorFlow backend.
# **** Ingreso de parametros ****
#
#  Modelo a utilizar:
#  VGG16 --> Ingresar 0
#  VGG19 --> Ingresar 1
# 1
# Tipo de set de datos:
#  Diurno --> Ingresar 0
#  Nocturno --> Ingresar 1
# 0
# prediccion N°: 1
# animal detectado: Vaca
# np.max(preds): 1.0
# preds: [[3.62794379e-37 1.53088275e-33 1.78911616e-31 7.86559675e-18
#   3.60899589e-27 1.00000000e+00]]
#
#
# prediccion N°: 2
# animal detectado: Puma
# np.max(preds): 0.9994622
# preds: [[5.1825034e-04 1.4392236e-10 2.8468965e-09 1.9519637e-05 9.9946219e-01
#   4.5490799e-11]]
#
#
# prediccion N°: 3
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[1.33901145e-14 2.69273807e-15 1.00000000e+00 1.28084647e-21
#   4.93611177e-20 1.21898887e-21]]
#
#
# prediccion N°: 4
# animal detectado: Carpincho
# np.max(preds): 0.90837187
# preds: [[9.0837187e-01 6.2504980e-11 9.1624007e-02 4.4273559e-08 4.7537907e-09
#   4.1490734e-06]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 5
# animal detectado: Carpincho
# np.max(preds): 1.0
# preds: [[1.0000000e+00 4.6699585e-13 1.9332388e-19 1.8081978e-23 1.2065044e-18
#   7.6211054e-16]]
#
#
# prediccion N°: 6
# animal detectado: Carpincho
# np.max(preds): 1.0
# preds: [[1.0000000e+00 1.6910504e-20 3.6512790e-24 3.7379531e-31 4.3923841e-18
#   9.0260960e-28]]
#
#
# prediccion N°: 7
# animal detectado: Carpincho
# np.max(preds): 1.0
# preds: [[1.0000000e+00 1.7123741e-21 3.0365100e-25 1.4336609e-19 9.4697357e-21
#   4.6274104e-23]]
#
#
# prediccion N°: 8
# animal detectado: Carpincho
# np.max(preds): 1.0
# preds: [[1.0000000e+00 3.5877354e-26 4.4802190e-30 1.8434234e-25 4.2588372e-25
#   1.6513482e-20]]
#
#
# prediccion N°: 9
# animal detectado: Carpincho
# np.max(preds): 1.0
# preds: [[1.0000000e+00 2.6812241e-25 7.9483568e-27 2.6268122e-22 7.3469037e-28
#   2.9924675e-18]]
#
#
# prediccion N°: 10
# animal detectado: Carpincho
# np.max(preds): 1.0
# preds: [[1.0000000e+00 3.6203105e-23 6.3238039e-25 9.2132303e-18 1.4549592e-21
#   1.2818437e-21]]
#
#
# prediccion N°: 11
# animal detectado: Carpincho
# np.max(preds): 0.9947476
# preds: [[9.9474758e-01 5.8319490e-19 5.1164166e-03 1.3601540e-04 4.3837559e-10
#   7.2020209e-18]]
#
#
# prediccion N°: 12
# animal detectado: Carpincho
# np.max(preds): 1.0
# preds: [[1.0000000e+00 7.7484826e-22 7.9904904e-20 4.8299502e-16 1.6216196e-22
#   1.0022341e-15]]
#
#
# prediccion N°: 13
# animal detectado: Carpincho
# np.max(preds): 1.0
# preds: [[1.0000000e+00 6.9137024e-24 1.6880982e-13 2.1874487e-11 3.4840057e-18
#   5.5630755e-17]]
#
#
# prediccion N°: 14
# animal detectado: Carpincho
# np.max(preds): 0.9999043
# preds: [[9.9990427e-01 7.2148744e-18 2.3234881e-17 9.5719020e-05 3.7571193e-10
#   2.0174780e-12]]
#
#
# prediccion N°: 15
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[2.9541134e-30 1.3792705e-25 1.0000000e+00 8.7053174e-35 4.2405123e-13
#   1.8178911e-34]]
#
#
# prediccion N°: 16
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[1.7757905e-22 1.2267258e-24 1.0000000e+00 7.1356522e-14 3.5042844e-15
#   1.4094587e-20]]
#
#
# prediccion N°: 17
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[2.8076945e-23 6.7444923e-29 1.0000000e+00 6.3940312e-24 2.0407250e-10
#   8.6016268e-29]]
#
#
# prediccion N°: 18
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[3.1828117e-29 2.2020585e-26 1.0000000e+00 1.1883091e-37 6.4151107e-18
#   4.4389641e-38]]
#
#
# prediccion N°: 19
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[2.4696285e-23 3.6041874e-16 1.0000000e+00 1.5619119e-24 4.0119366e-16
#   4.5994356e-35]]
#
#
# prediccion N°: 20
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[5.0867601e-21 1.1390868e-21 1.0000000e+00 1.4027739e-22 5.3084617e-11
#   2.8556728e-25]]
#
#
# prediccion N°: 21
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[4.2524456e-23 2.0398299e-25 1.0000000e+00 5.9268425e-22 7.2301365e-19
#   1.0288115e-30]]
#
#
# prediccion N°: 22
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[7.0123815e-23 5.2116988e-22 1.0000000e+00 5.7816222e-23 2.1258846e-16
#   2.6819784e-27]]
#
#
# prediccion N°: 23
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[1.9426447e-24 5.5935623e-27 1.0000000e+00 5.2280438e-23 2.0924538e-17
#   1.5572259e-29]]
#
#
# prediccion N°: 24
# animal detectado: Gato montes
# np.max(preds): 0.99609864
# preds: [[2.2210810e-07 1.8121058e-03 9.9609864e-01 4.1700055e-10 2.0890336e-03
#   1.3347586e-08]]
#
#
# prediccion N°: 25
# animal detectado: Vaca
# np.max(preds): 0.99458045
# preds: [[4.2991992e-08 7.0367725e-17 9.2999647e-19 5.4195360e-03 1.5314242e-16
#   9.9458045e-01]]
#
#
# prediccion N°: 26
# animal detectado: Vaca
# np.max(preds): 0.99999964
# preds: [[5.4350818e-15 8.1068654e-09 3.8005233e-17 3.1618617e-07 4.2019706e-16
#   9.9999964e-01]]
#
#
# prediccion N°: 27
# animal detectado: Ciervo
# np.max(preds): 0.9976591
# preds: [[3.25098867e-04 9.97659087e-01 7.41496065e-09 1.00757046e-04
#   1.00877719e-06 1.91398221e-03]]
#
#
# prediccion N°: 28
# animal detectado: Vaca
# np.max(preds): 0.99534625
# preds: [[5.0468559e-19 3.8524895e-11 2.3840447e-29 4.6537495e-03 2.4063295e-14
#   9.9534625e-01]]
#
#
# prediccion N°: 29
# animal detectado: Vaca
# np.max(preds): 1.0
# preds: [[9.4975641e-27 1.2598224e-18 7.0092411e-26 9.1748407e-15 1.4396520e-25
#   1.0000000e+00]]
#
#
# prediccion N°: 30
# animal detectado: Vaca
# np.max(preds): 0.9960503
# preds: [[1.2257405e-18 7.3492532e-11 1.1651806e-15 3.9497265e-03 3.0406888e-18
#   9.9605030e-01]]
#
#
# prediccion N°: 31
# animal detectado: Vaca
# np.max(preds): 0.5556681
# preds: [[2.4152627e-05 2.5164959e-09 1.5878049e-03 4.4271988e-01 5.0828241e-08
#   5.5566812e-01]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 32
# animal detectado: Vaca
# np.max(preds): 0.5394382
# preds: [[1.7938474e-11 7.6286647e-14 1.3258496e-15 4.6056181e-01 3.5218842e-10
#   5.3943819e-01]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 33
# animal detectado: Vaca
# np.max(preds): 1.0
# preds: [[1.1424759e-15 3.6004453e-11 3.0185198e-23 1.6465633e-10 1.0579775e-21
#   1.0000000e+00]]
#
#
# prediccion N°: 34
# animal detectado: Ciervo
# np.max(preds): 1.0
# preds: [[1.8451597e-19 1.0000000e+00 4.9386020e-11 9.8808925e-09 2.4494153e-11
#   1.1930459e-08]]
#
#
# prediccion N°: 35
# animal detectado: Ciervo
# np.max(preds): 0.99998593
# preds: [[1.8967194e-24 9.9998593e-01 1.4079289e-05 9.8819521e-18 4.6879363e-21
#   4.7383866e-28]]
#
#
# prediccion N°: 36
# animal detectado: Ciervo
# np.max(preds): 0.9999908
# preds: [[5.9799892e-25 9.9999082e-01 1.3342674e-14 9.1621714e-06 3.2348267e-15
#   4.5813232e-12]]
#
#
# prediccion N°: 37
# animal detectado: Ciervo
# np.max(preds): 1.0
# preds: [[1.5757606e-31 1.0000000e+00 1.5408113e-13 7.3108271e-16 1.3610608e-25
#   1.2915143e-19]]
#
#
# prediccion N°: 38
# animal detectado: Vaca
# np.max(preds): 0.99998796
# preds: [[6.7827310e-35 5.7285587e-07 1.0411121e-24 4.8454354e-14 1.1479638e-05
#   9.9998796e-01]]
#
#
# prediccion N°: 39
# animal detectado: Ciervo
# np.max(preds): 0.9989397
# preds: [[4.8411626e-09 9.9893969e-01 1.0577125e-03 8.7424352e-09 2.6590337e-06
#   1.4480260e-14]]
#
#
# prediccion N°: 40
# animal detectado: Ciervo
# np.max(preds): 1.0
# preds: [[2.03013011e-14 1.00000000e+00 9.11906141e-12 1.46933610e-09
#   1.06066855e-14 9.50005387e-14]]
#
#
# prediccion N°: 41
# animal detectado: Ciervo
# np.max(preds): 0.89483494
# preds: [[1.1334969e-15 8.9483494e-01 7.9071656e-02 2.5947263e-02 1.4613051e-04
#   2.8067557e-10]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 42
# animal detectado: Ciervo
# np.max(preds): 0.9999591
# preds: [[1.3371131e-08 9.9995911e-01 1.8776113e-11 4.7809232e-07 4.0430903e-05
#   3.4513486e-11]]
#
#
# prediccion N°: 43
# animal detectado: Puma
# np.max(preds): 1.0
# preds: [[8.2488566e-27 1.7682009e-28 1.6308624e-15 4.0385285e-25 1.0000000e+00
#   8.6365421e-22]]
#
#
# prediccion N°: 44
# animal detectado: Puma
# np.max(preds): 0.96395
# preds: [[5.3582273e-19 5.0956036e-12 3.6049992e-02 4.1002110e-14 9.6394998e-01
#   9.2732538e-17]]
#
#
# prediccion N°: 45
# animal detectado: Puma
# np.max(preds): 1.0
# preds: [[5.4621358e-26 7.6604211e-17 1.7495626e-12 1.4876554e-23 1.0000000e+00
#   2.6103501e-22]]
#
#
# prediccion N°: 46
# animal detectado: Puma
# np.max(preds): 0.99986017
# preds: [[5.7058210e-15 1.3980929e-04 7.9156022e-11 4.1215856e-08 9.9986017e-01
#   1.7538732e-14]]
#
#
# prediccion N°: 47
# animal detectado: Oveja
# np.max(preds): 0.6864691
# preds: [[1.61392990e-07 3.13335538e-01 3.33332899e-08 6.86469078e-01
#   8.86243070e-05 1.06660176e-04]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 48
# animal detectado: Gato montes
# np.max(preds): 0.99999976
# preds: [[6.3726191e-11 2.5677534e-07 9.9999976e-01 2.7229233e-13 1.6954899e-10
#   5.3614726e-12]]
#
#
# prediccion N°: 49
# animal detectado: Puma
# np.max(preds): 1.0
# preds: [[4.3161639e-17 2.7959247e-17 1.7507144e-08 2.3452177e-16 1.0000000e+00
#   3.1428479e-24]]
#
#
# prediccion N°: 50
# animal detectado: Gato montes
# np.max(preds): 0.99998677
# preds: [[8.84663924e-13 1.48317469e-10 9.99986768e-01 7.01983993e-07
#   1.15039975e-05 1.05187496e-06]]
# prediccion N°: 51
# animal detectado: Oveja
# np.max(preds): 0.5476951
# preds: [[4.5085865e-01 1.4290191e-03 3.2954376e-06 5.4769510e-01 1.3938393e-05
#   5.0477230e-08]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 52
# animal detectado: Puma
# np.max(preds): 0.9916679
# preds: [[1.2367151e-14 1.7304355e-07 8.3318986e-03 2.3401886e-19 9.9166793e-01
#   9.6498824e-18]]
#
#
# prediccion N°: 53
# animal detectado: Oveja
# np.max(preds): 1.0
# preds: [[1.0367082e-12 2.9901893e-23 6.9248424e-31 1.0000000e+00 6.9985405e-30
#   1.0248258e-19]]
#
#
# prediccion N°: 54
# animal detectado: Oveja
# np.max(preds): 0.97973436
# preds: [[3.7932256e-16 5.5494200e-11 1.8930203e-19 9.7973436e-01 3.9602859e-14
#   2.0265594e-02]]
#
#
# prediccion N°: 55
# animal detectado: Oveja
# np.max(preds): 1.0
# preds: [[1.02520666e-16 8.15163095e-13 1.58141181e-20 1.00000000e+00
#   1.06795550e-08 1.59179577e-15]]
#
#
# prediccion N°: 56
# animal detectado: Oveja
# np.max(preds): 1.0
# preds: [[1.8588794e-12 1.1694904e-27 4.4298744e-18 1.0000000e+00 5.1191141e-28
#   3.4211574e-18]]
#
#
# prediccion N°: 57
# animal detectado: Oveja
# np.max(preds): 1.0
# preds: [[9.8862084e-24 4.7594207e-25 6.2321179e-29 1.0000000e+00 4.4936920e-29
#   2.4309051e-15]]
#
#
# prediccion N°: 58
# animal detectado: Oveja
# np.max(preds): 0.99999917
# preds: [[5.14743411e-17 7.08102158e-25 1.98946350e-23 9.99999166e-01
#   1.14696456e-29 7.87815623e-07]]
#
#
# prediccion N°: 59
# animal detectado: Oveja
# np.max(preds): 1.0
# preds: [[2.3955270e-16 8.2964075e-21 5.9827307e-27 1.0000000e+00 2.1601615e-31
#   7.8886227e-16]]
#
#
# prediccion N°: 60
# animal detectado: Oveja
# np.max(preds): 1.0
# preds: [[4.8529990e-16 8.0137161e-21 1.7967453e-35 1.0000000e+00 1.0669285e-17
#   1.1765521e-11]]
#
#
# prediccion N°: 61
# animal detectado: Ciervo
# np.max(preds): 0.5483145
# preds: [[6.1287056e-17 5.4831451e-01 4.5856081e-15 4.5168552e-01 8.2831609e-13
#   3.1346364e-08]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 62
# animal detectado: Oveja
# np.max(preds): 1.0
# preds: [[7.0361147e-25 5.4066652e-17 3.3627766e-18 1.0000000e+00 5.1367228e-19
#   4.1540177e-15]]
#
#
# prediccion N°: 63
# animal detectado: Carpincho
# np.max(preds): 1.0
# preds: [[1.00000000e+00 1.03222314e-16 1.69678424e-10 1.78999864e-14
#   4.30994885e-15 4.24772005e-19]]
#
#
# prediccion N°: 64
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[2.5847133e-09 6.9485344e-21 1.0000000e+00 9.6981589e-12 2.9050423e-08
#   9.4383767e-10]]
#
#
# prediccion N°: 65
# animal detectado: Gato montes
# np.max(preds): 0.9999958
# preds: [[7.4351391e-08 2.1916205e-07 9.9999583e-01 3.9468791e-06 2.8672832e-12
#   5.7517725e-14]]
#
#
# prediccion N°: 66
# animal detectado: Gato montes
# np.max(preds): 0.9999863
# preds: [[1.3706011e-05 4.2056348e-16 9.9998629e-01 1.8507875e-12 7.6534135e-12
#   2.0171668e-19]]
#
#
# prediccion N°: 67
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[1.64350835e-16 1.19541938e-23 1.00000000e+00 1.04101078e-14
#   6.01770153e-13 1.05651295e-22]]
#
#
# prediccion N°: 68
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[6.5259634e-17 1.2571698e-22 1.0000000e+00 1.1738832e-21 7.6099149e-10
#   4.4444277e-27]]
#
#
# prediccion N°: 69
# animal detectado: Gato montes
# np.max(preds): 0.9999999
# preds: [[3.5043073e-17 1.4372836e-07 9.9999988e-01 9.5232437e-13 1.9188038e-09
#   9.4734730e-25]]
#
#
# prediccion N°: 70
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[1.2670158e-14 2.1396433e-15 1.0000000e+00 8.9949414e-16 4.8965713e-15
#   3.9834760e-18]]
#
#
# prediccion N°: 71
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[1.55219447e-24 4.19584561e-27 1.00000000e+00 3.14763032e-27
#   2.70387616e-22 1.00072505e-30]]
#
#
# prediccion N°: 72
# animal detectado: Gato montes
# np.max(preds): 1.0
# preds: [[3.0077351e-25 3.4204352e-28 1.0000000e+00 2.6017607e-22 8.7078312e-30
#   3.3107267e-35]]
#
#
# prediccion N°: 73
# animal detectado: Gato montes
# np.max(preds): 0.99995375
# preds: [[1.1171166e-24 4.6198664e-05 9.9995375e-01 2.5240184e-17 2.9295311e-18
#   1.1962582e-23]]
#
#
# prediccion N°: 74
# animal detectado: Vaca
# np.max(preds): 0.9788593
# preds: [[1.5175720e-10 2.5878575e-09 1.9679313e-05 1.2439516e-11 2.1120990e-02
#   9.7885931e-01]]
#
#
# prediccion N°: 75
# animal detectado: Ciervo
# np.max(preds): 0.9232078
# preds: [[4.9600959e-11 9.2320782e-01 9.6333417e-07 1.0930843e-06 3.5822025e-04
#   7.6431833e-02]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 76
# animal detectado: Vaca
# np.max(preds): 0.7527749
# preds: [[3.3131343e-08 1.2751875e-04 3.4619065e-11 2.4709752e-01 1.0376359e-08
#   7.5277489e-01]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 77
# animal detectado: Ciervo
# np.max(preds): 0.9999504
# preds: [[2.0407524e-06 9.9995041e-01 4.6589430e-06 5.3085687e-09 4.2938394e-05
#   2.9353307e-08]]
#
#
# prediccion N°: 78
# animal detectado: Ciervo
# np.max(preds): 0.99999726
# preds: [[4.7463911e-32 9.9999726e-01 1.5931693e-09 2.7924045e-06 7.7927609e-11
#   1.3585710e-12]]
#
#
# prediccion N°: 79
# animal detectado: Ciervo
# np.max(preds): 0.99999404
# preds: [[4.9160172e-11 9.9999404e-01 6.0162415e-06 3.4392767e-16 2.1240648e-08
#   5.1527344e-16]]
#
#
# prediccion N°: 80
# animal detectado: Ciervo
# np.max(preds): 0.9999908
# preds: [[3.9793052e-27 9.9999082e-01 3.1518020e-15 9.0988534e-13 9.2091250e-06
#   2.8795952e-08]]
#
#
# prediccion N°: 81
# animal detectado: Ciervo
# np.max(preds): 0.9986959
# preds: [[2.4101755e-07 9.9869591e-01 1.9732110e-04 1.1055171e-03 1.5425094e-07
#   8.9338710e-07]]
#
#
# prediccion N°: 82
# animal detectado: Ciervo
# np.max(preds): 1.0
# preds: [[5.2551504e-18 1.0000000e+00 3.4626613e-10 1.7208037e-11 6.5340259e-12
#   1.8197255e-16]]
#
#
# prediccion N°: 83
# animal detectado: Ciervo
# np.max(preds): 1.0
# preds: [[4.5398958e-17 1.0000000e+00 2.9717697e-14 4.3635346e-14 5.4386617e-11
#   4.1814499e-12]]
#
#
# prediccion N°: 84
# animal detectado: Ciervo
# np.max(preds): 0.9999957
# preds: [[6.7281661e-08 9.9999571e-01 1.5485644e-14 4.8240790e-14 4.1415356e-06
#   6.6121423e-08]]
#
#
# prediccion N°: 85
# animal detectado: Ciervo
# np.max(preds): 0.99938715
# preds: [[6.00246654e-04 9.99387145e-01 5.88597800e-07 1.55090092e-08
#   1.20690975e-05 4.71281555e-17]]
#
#
# prediccion N°: 86
# animal detectado: Gato montes
# np.max(preds): 0.6220697
# preds: [[1.8984353e-17 3.7792665e-01 6.2206972e-01 2.4532969e-06 5.7638707e-12
#   1.1591737e-06]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 87
# animal detectado: Puma
# np.max(preds): 1.0
# preds: [[1.8430996e-18 1.4018241e-11 7.7250117e-09 7.0178835e-11 1.0000000e+00
#   4.7554630e-18]]
#
#
# prediccion N°: 88
# animal detectado: Ciervo
# np.max(preds): 0.85803586
# preds: [[1.4176054e-01 8.5803586e-01 2.9427176e-11 1.2191894e-07 1.7782017e-04
#   2.5695721e-05]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 89
# animal detectado: Puma
# np.max(preds): 0.54889125
# preds: [[1.0469145e-08 1.6949516e-02 3.4769883e-04 4.3381137e-01 5.4889125e-01
#   1.0402390e-07]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 90
# animal detectado: Puma
# np.max(preds): 0.9931993
# preds: [[2.0295108e-15 1.8756564e-03 2.7467390e-08 9.9713343e-06 9.9319929e-01
#   4.9150754e-03]]
#
#
# prediccion N°: 91
# animal detectado: Puma
# np.max(preds): 0.999977
# preds: [[3.6040922e-15 1.8245447e-06 1.9614831e-10 1.8595334e-10 9.9997699e-01
#   2.1274782e-05]]
#
#
# prediccion N°: 92
# animal detectado: Puma
# np.max(preds): 0.9008908
# preds: [[7.95140253e-14 1.10442878e-03 1.28488969e-10 1.22147925e-11
#   9.00890827e-01 9.80047137e-02]]
# porcentaje de certeza menor al 95.0% --> Objeto desconocido
#
#
# prediccion N°: 93
# animal detectado: Puma
# np.max(preds): 1.0
# preds: [[1.5288285e-33 5.5487258e-25 9.3234288e-19 7.7524106e-23 1.0000000e+00
#   4.4566367e-26]]
#
#
# prediccion N°: 94
# animal detectado: Gato montes
# np.max(preds): 0.99963737
# preds: [[9.0738919e-09 1.6469635e-04 9.9963737e-01 2.2381959e-10 1.9722705e-04
#   7.1559015e-07]]
#
#
# prediccion N°: 95
# animal detectado: Puma
# np.max(preds): 0.99998736
# preds: [[1.9460384e-25 3.4305419e-15 1.2665368e-05 3.8655462e-15 9.9998736e-01
#   3.8531664e-14]]
#
#
# prediccion N°: 96
# animal detectado: Gato montes
# np.max(preds): 0.995846
# preds: [[1.3605910e-12 3.5744142e-03 9.9584597e-01 6.1809978e-06 5.7351473e-04
#   8.8027974e-10]]
#
#
# prediccion N°: 97
# animal detectado: Ciervo
# np.max(preds): 1.0
# preds: [[4.7778594e-13 1.0000000e+00 1.3842006e-15 9.2353165e-13 3.1156095e-08
#   3.8349938e-11]]
#
#
# prediccion N°: 98
# animal detectado: Ciervo
# np.max(preds): 0.99061525
# preds: [[3.4305089e-08 9.9061525e-01 3.0418745e-14 3.1659275e-03 6.1553232e-03
#   6.3531792e-05]]
#
#
# prediccion N°: 99
# animal detectado: Oveja
# np.max(preds): 1.0
# preds: [[8.9280282e-19 6.2045938e-24 3.7971899e-33 1.0000000e+00 8.9631480e-25
#   9.8360779e-14]]
#
#
# prediccion N°: 100
# animal detectado: Oveja
# np.max(preds): 1.0
# preds: [[7.9308744e-21 1.8504360e-15 1.0893542e-18 1.0000000e+00 9.2549861e-15
#   3.9464924e-12]]
